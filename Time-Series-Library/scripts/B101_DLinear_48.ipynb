# %%
# !bash train_DLinear_B101_48.sh
# Out:
# ========================================
# Avvio training per il modello: DLinear con finestra48
# ========================================
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           B101_48_48          Model:              DLinear
#
# Data Loader
#   Data:               custom              Root Path:          ../data/final/
#   Data Path:          B101_50khz_downsampled_reduced.csvFeatures:           M
#   Target:             Channel35           Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            48                  Label Len:          24
#   Pred Len:           48                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             62                  Dec In:             62
#   C Out:              62                  d model:            512
#   n heads:            8                   e layers:           7
#   d layers:           4                   d FF:               2048
#   Moving Avg:         25                  Factor:             10
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       10                  Batch Size:         64
#   Patience:           3                   Learning Rate:      0.001
#   Des:                forecasting_48      Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_B101_48_48_DLinear_custom_ftM_sl48_ll24_pl48_dm512_nh8_el7_dl4_df2048_expand2_dc4_fc10_ebtimeF_dtTrue_forecasting_48_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 195905
# val 27953
# test 55953
# 	iters: 100, epoch: 1 | loss: 0.9438818
# 	speed: 0.0122s/iter; left time: 371.2164s
# 	iters: 200, epoch: 1 | loss: 0.9991466
# 	speed: 0.0056s/iter; left time: 171.5864s
# 	iters: 300, epoch: 1 | loss: 0.9924347
# 	speed: 0.0056s/iter; left time: 168.8053s
# 	iters: 400, epoch: 1 | loss: 0.9710361
# 	speed: 0.0058s/iter; left time: 175.9905s
# 	iters: 500, epoch: 1 | loss: 1.0425452
# 	speed: 0.0056s/iter; left time: 167.9571s
# 	iters: 600, epoch: 1 | loss: 0.9554662
# 	speed: 0.0057s/iter; left time: 171.4982s
# 	iters: 700, epoch: 1 | loss: 0.9356365
# 	speed: 0.0057s/iter; left time: 170.9365s
# 	iters: 800, epoch: 1 | loss: 0.9679036
# 	speed: 0.0057s/iter; left time: 168.8924s
# 	iters: 900, epoch: 1 | loss: 0.9904411
# 	speed: 0.0055s/iter; left time: 164.8276s
# 	iters: 1000, epoch: 1 | loss: 1.0010517
# 	speed: 0.0054s/iter; left time: 161.3201s
# 	iters: 1100, epoch: 1 | loss: 0.9967988
# 	speed: 0.0056s/iter; left time: 164.8945s
# 	iters: 1200, epoch: 1 | loss: 0.9012839
# 	speed: 0.0060s/iter; left time: 175.3175s
# 	iters: 1300, epoch: 1 | loss: 0.9863837
# 	speed: 0.0061s/iter; left time: 178.4734s
# 	iters: 1400, epoch: 1 | loss: 0.9736913
# 	speed: 0.0061s/iter; left time: 178.4195s
# 	iters: 1500, epoch: 1 | loss: 0.9932113
# 	speed: 0.0061s/iter; left time: 178.6579s
# 	iters: 1600, epoch: 1 | loss: 0.9320905
# 	speed: 0.0060s/iter; left time: 173.1831s
# 	iters: 1700, epoch: 1 | loss: 0.9855804
# 	speed: 0.0061s/iter; left time: 176.1668s
# 	iters: 1800, epoch: 1 | loss: 0.9607673
# 	speed: 0.0061s/iter; left time: 174.4630s
# 	iters: 1900, epoch: 1 | loss: 0.9260664
# 	speed: 0.0062s/iter; left time: 178.4371s
# 	iters: 2000, epoch: 1 | loss: 0.9983056
# 	speed: 0.0060s/iter; left time: 172.8537s
# 	iters: 2100, epoch: 1 | loss: 1.0090872
# 	speed: 0.0061s/iter; left time: 173.3450s
# 	iters: 2200, epoch: 1 | loss: 1.0072271
# 	speed: 0.0060s/iter; left time: 1.5768s
# 	iters: 2900, epoch: 10 | loss: 0.9512156
# 	speed: 0.0059s/iter; left time: 0.9601s
# 	iters: 3000, epoch: 10 | loss: 0.9686737
# 	speed: 0.0061s/iter; left time: 0.3856s
# Epoch: 10 cost time: 18.82956290245056
# Epoch: 10, Steps: 3062 | Train Loss: 0.9759354 Vali Loss: 0.9511633 Test Loss: 0.9309587
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.953125e-06
# >>>>>>>testing : long_term_forecast_B101_48_48_DLinear_custom_ftM_sl48_ll24_pl48_dm512_nh8_el7_dl4_df2048_expand2_dc4_fc10_ebtimeF_dtTrue_forecasting_48_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 55953
# test shape: (55953, 48, 62) (55953, 48, 62)
# test shape: (55953, 48, 62) (55953, 48, 62)
# mse:0.9310342669487, mae:0.7421237826347351, dtw:Not calculated
# Training completato per DLinear.

# %%
import numpy as np
import matplotlib.pyplot as plt

# CI HA IMPIEGATO 93 MINUTI

# Sostituisci con il tuo setting o percorso
setting = 'long_term_forecast_B101_48_48_DLinear_custom_ftM_sl48_ll24_pl48_dm512_nh8_el7_dl4_df2048_expand2_dc4_fc10_ebtimeF_dtTrue_forecasting_48_0'
metrics_path = 'results/' + setting + '/metrics.npy'
pred_path = 'results/' + setting + '/pred.npy'
true_path = 'results/' + setting + '/true.npy'

# Caricamento dei file
metrics = np.load(metrics_path)
preds = np.load(pred_path)
trues = np.load(true_path)

# Stampa delle forme per verifica
print("Shape metrics:", metrics.shape)
print("Shape preds:", preds.shape)
print("Shape trues:", trues.shape)

# Stampa opzionale delle metriche
print("Metrics:\n", metrics)

# Assumiamo che la forma di preds e trues sia (n_samples, L, n_channels)
n_samples, L, n_channels = trues.shape

# Generiamo i nomi dei canali (1..n_channels)
variables = [f'Channel{i}' for i in range(1, n_channels + 1)]

# Seleziona il sample da plottare
idx_sample = 0  # cambia se vuoi visualizzare altri sample

# Plot per ogni variabile (canale)
for i, var_name in enumerate(variables):
    plt.figure(figsize=(8, 5))
    # Ground Truth
    plt.plot(
        trues[idx_sample, :, i],
        label=f'GroundTruth ({var_name})',
        color='blue'
    )
    # Prediction
    plt.plot(
        preds[idx_sample, :, i],
        label=f'Prediction ({var_name})',
        color='orange',
        linestyle='--'
    )
    plt.title(f'Confronto - Variabile: {var_name} (Sample {idx_sample})')
    plt.xlabel('Time Step')
    plt.ylabel(var_name)
    plt.legend()
    plt.show()
# Out:
# Shape metrics: (5,)
# Shape preds: (55953, 48, 62)
# Shape trues: (55953, 48, 62)
# Metrics:
#  [7.4212378e-01 9.3103427e-01 9.6490115e-01 1.7447343e+00 6.7596977e+04]

# %%
# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

for i, var_name in enumerate(variables):
    y_true = trues[:, :, i].flatten()  # Ground truth per la variabile i
    y_pred = preds[:, :, i].flatten()  # Predizioni per la variabile i
    
    print(f"\n--- Metriche per la variabile: {var_name} ---")
    print(f"MAE : {mae(y_true, y_pred):.4f}")
    print(f"MSE : {mse(y_true, y_pred):.4f}")
    print(f"RMSE: {rmse(y_true, y_pred):.4f}")
# Out:
# --- Metriche per la variabile: Channel1 ---
# MAE : 0.7403
# MSE : 0.9252
# RMSE: 0.9619
#
# --- Metriche per la variabile: Channel2 ---
# MAE : 0.7360
# MSE : 0.9176
# RMSE: 0.9579
#
# --- Metriche per la variabile: Channel3 ---
# MAE : 0.7408
# MSE : 0.9271
# RMSE: 0.9629
#
# --- Metriche per la variabile: Channel4 ---
# MAE : 0.7394
# MSE : 0.9252
# RMSE: 0.9619
#
# --- Metriche per la variabile: Channel5 ---
# MAE : 0.7440
# MSE : 0.9378
# RMSE: 0.9684
#
# --- Metriche per la variabile: Channel6 ---
# MAE : 0.7459
# MSE : 0.9409
# RMSE: 0.9700
#
# --- Metriche per la variabile: Channel7 ---
# MAE : 0.7449
# MSE : 0.9375
# RMSE: 0.9682
#
# --- Metriche per la variabile: Channel8 ---
# MAE : 0.7462
# MSE : 0.9410
# RMSE: 0.9701
#
# --- Metriche per la variabile: Channel9 ---
# MAE : 0.7422
# MSE : 0.9272
# RMSE: 0.9629
#
# --- Metriche per la variabile: Channel10 ---
# MAE : 0.7436
# MSE : 0.9292
# RMSE: 0.9640
#
# --- Metriche per la variabile: Channel11 ---
# MAE : 0.7422
# MSE : 0.9255
# RMSE: 0.9620
#
# --- Metriche per la variabile: Channel12 ---
# MAE : 0.7398
# MSE : 0.9277
# RMSE: 0.9632
#
# --- Metriche per la variabile: Channel13 ---
# MAE : 0.7380
# MSE : 0.9193
# RMSE: 0.9588
#
# --- Metriche per la variabile: Channel14 ---
# MAE : 0.7379
# MSE : 0.9139
# RMSE: 0.9560
#
# --- Metriche per la variabile: Channel15 ---
# MAE : 0.7399
# MSE : 0.9272
# RMSE: 0.9629
#
# --- Metriche per la variabile: Channel16 ---
# MAE : 0.7366
# MSE : 0.9132
# RMSE: 0.9556
#
# --- Metriche per la variabile: Channel17 ---
# MAE : 0.7404
# MSE : 0.9231
# RMSE: 0.9608
#
# --- Metriche per la variabile: Channel18 ---
# MAE : 0.7383
# MSE : 0.9212
# RMSE: 0.9598
#
# --- Metriche per la variabile: Channel19 ---
# MAE : 0.7417
# MSE : 0.9270
# RMSE: 0.9628
#
# --- Metriche per la variabile: Channel20 ---
# MAE : 0.7409
# MSE : 0.9306
# RMSE: 0.9647
#
# --- Metriche per la variabile: Channel21 ---
# MAE : 0.7391
# MSE : 0.9218
# RMSE: 0.9601
#
# --- Metriche per la variabile: Channel22 ---
# MAE : 0.7446
# MSE : 0.9350
# RMSE: 0.9670
#
# --- Metriche per la variabile: Channel23 ---
# MAE : 0.7438
# MSE : 0.9275
# RMSE: 0.9631
#
# --- Metriche per la variabile: Channel24 ---
# MAE : 0.7445
# MSE : 0.9383
# RMSE: 0.9687
#
# --- Metriche per la variabile: Channel25 ---
# MAE : 0.7462
# MSE : 0.9363
# RMSE: 0.9676
#
# --- Metriche per la variabile: Channel26 ---
# MAE : 0.7471
# MSE : 0.9393
# RMSE: 0.9692
#
# --- Metriche per la variabile: Channel27 ---
# MAE : 0.7501
# MSE : 0.9514
# RMSE: 0.9754
#
# --- Metriche per la variabile: Channel28 ---
# MAE : 0.7455
# MSE : 0.9401
# RMSE: 0.9696
#
# --- Metriche per la variabile: Channel29 ---
# MAE : 0.7455
# MSE : 0.9367
# RMSE: 0.9678
#
# --- Metriche per la variabile: Channel30 ---
# MAE : 0.7441
# MSE : 0.9355
# RMSE: 0.9672
#
# --- Metriche per la variabile: Channel31 ---
# MAE : 0.7493
# MSE : 0.9531
# RMSE: 0.9762
#
# --- Metriche per la variabile: Channel32 ---
# MAE : 0.7436
# MSE : 0.9415
# RMSE: 0.9703
#
# --- Metriche per la variabile: Channel33 ---
# MAE : 0.7410
# MSE : 0.9288
# RMSE: 0.9638
#
# --- Metriche per la variabile: Channel34 ---
# MAE : 0.7362
# MSE : 0.9179
# RMSE: 0.9581
#
# --- Metriche per la variabile: Channel35 ---
# MAE : 0.7362
# MSE : 0.9167
# RMSE: 0.9575
#
# --- Metriche per la variabile: Channel36 ---
# MAE : 0.7410
# MSE : 0.9312
# RMSE: 0.9650
#
# --- Metriche per la variabile: Channel37 ---
# MAE : 0.7386
# MSE : 0.9065
# RMSE: 0.9521
#
# --- Metriche per la variabile: Channel38 ---
# MAE : 0.7431
# MSE : 0.9341
# RMSE: 0.9665
#
# --- Metriche per la variabile: Channel39 ---
# MAE : 0.7403
# MSE : 0.9263
# RMSE: 0.9624
#
# --- Metriche per la variabile: Channel40 ---
# MAE : 0.7420
# MSE : 0.9356
# RMSE: 0.9673
#
# --- Metriche per la variabile: Channel41 ---
# MAE : 0.7440
# MSE : 0.9386
# RMSE: 0.9688
#
# --- Metriche per la variabile: Channel42 ---
# MAE : 0.7485
# MSE : 0.9464
# RMSE: 0.9728
#
# --- Metriche per la variabile: Channel43 ---
# MAE : 0.7496
# MSE : 0.9545
# RMSE: 0.9770
#
# --- Metriche per la variabile: Channel44 ---
# MAE : 0.7434
# MSE : 0.9362
# RMSE: 0.9675
#
# --- Metriche per la variabile: Channel45 ---
# MAE : 0.7508
# MSE : 0.9547
# RMSE: 0.9771
#
# --- Metriche per la variabile: Channel46 ---
# MAE : 0.7415
# MSE : 0.9303
# RMSE: 0.9645
#
# --- Metriche per la variabile: Channel47 ---
# MAE : 0.7432
# MSE : 0.9332
# RMSE: 0.9660
#
# --- Metriche per la variabile: Channel48 ---
# MAE : 0.7381
# MSE : 0.9273
# RMSE: 0.9630
#
# --- Metriche per la variabile: Channel49 ---
# MAE : 0.7437
# MSE : 0.9447
# RMSE: 0.9720
#
# --- Metriche per la variabile: Channel50 ---
# MAE : 0.7416
# MSE : 0.9337
# RMSE: 0.9663
#
# --- Metriche per la variabile: Channel51 ---
# MAE : 0.7525
# MSE : 0.9607
# RMSE: 0.9801
#
# --- Metriche per la variabile: Channel52 ---
# MAE : 0.7527
# MSE : 0.9538
# RMSE: 0.9766
#
# --- Metriche per la variabile: Channel53 ---
# MAE : 0.7670
# MSE : 1.0030
# RMSE: 1.0015
#
# --- Metriche per la variabile: Channel54 ---
# MAE : 0.7422
# MSE : 0.9303
# RMSE: 0.9645
#
# --- Metriche per la variabile: Channel55 ---
# MAE : 0.7374
# MSE : 0.9231
# RMSE: 0.9608
#
# --- Metriche per la variabile: Channel56 ---
# MAE : 0.7401
# MSE : 0.9318
# RMSE: 0.9653
#
# --- Metriche per la variabile: Channel57 ---
# MAE : 0.7452
# MSE : 0.9442
# RMSE: 0.9717
#
# --- Metriche per la variabile: Channel58 ---
# MAE : 0.7412
# MSE : 0.9216
# RMSE: 0.9600
#
# --- Metriche per la variabile: Channel59 ---
# MAE : 0.7404
# MSE : 0.9213
# RMSE: 0.9598
#
# --- Metriche per la variabile: Channel60 ---
# MAE : 0.7590
# MSE : 0.9574
# RMSE: 0.9785
#
# --- Metriche per la variabile: Channel61 ---
# MAE : 0.6732
# MSE : 0.7740
# RMSE: 0.8798
#
# --- Metriche per la variabile: Channel62 ---
# MAE : 0.7358
# MSE : 0.9124
# RMSE: 0.9552

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# Creazione di una lista per memorizzare le metriche
metrics_data = []

for i, var_name in enumerate(variables):
    y_true = trues[:, :, i].flatten()
    y_pred = preds[:, :, i].flatten()
    
    metrics_data.append([var_name, mae(y_true, y_pred), mse(y_true, y_pred), rmse(y_true, y_pred)])

# Creazione di un DataFrame
df_metrics = pd.DataFrame(metrics_data, columns=['Channel', 'MAE', 'MSE', 'RMSE'])

# Visualizzazione della tabella con matplotlib
fig, ax = plt.subplots(figsize=(8, 10))  # Dimensioni della figura
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_metrics.values, colLabels=df_metrics.columns, cellLoc = 'center', loc='center')

plt.show()

# Salva l'immagine nella cartella dei risultati
output_dir = f'./results/{setting}'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

fig.savefig(os.path.join(output_dir, 'metrics_table.png'))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# Calcola metriche per ciascun canale
mae_list, mse_list, rmse_list = [], [], []

for i in range(preds.shape[2]):
    y_true = trues[:, :, i].flatten()
    y_pred = preds[:, :, i].flatten()

    mae_list.append(mae(y_true, y_pred))
    mse_list.append(mse(y_true, y_pred))
    rmse_list.append(rmse(y_true, y_pred))

# Converti in array per analisi
mae_array = np.array(mae_list)
mse_array = np.array(mse_list)
rmse_array = np.array(rmse_list)

# Calcola statistiche
metrics = {'MAE': mae_array, 'MSE': mse_array, 'RMSE': rmse_array}

for metric_name, values in metrics.items():
    print(f"\n--- Analisi {metric_name} ---")
    print(f"Media: {np.mean(values):.4f}, Mediana: {np.median(values):.4f}")
    print(f"Min: {np.min(values):.4f}, Max: {np.max(values):.4f}")

    # Rileva anomalie con IQR
    Q1 = np.percentile(values, 25)
    Q3 = np.percentile(values, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    anomalies = np.where((values < lower_bound) | (values > upper_bound))[0]
    if len(anomalies) > 0:
        print(f"Anomalie rilevate nei canali: {anomalies + 1}")
    else:
        print("Nessuna anomalia rilevata.")

# Visualizza le metriche
plt.figure(figsize=(10, 6))
plt.plot(mae_list, label='MAE')
plt.plot(mse_list, label='MSE')
plt.plot(rmse_list, label='RMSE')
plt.xlabel('Channel')
plt.ylabel('Metric Value')
plt.title('Metriche per Canale')
plt.legend()
plt.show()
# Out:
# --- Analisi MAE ---
# Media: 0.7421, Mediana: 0.7422
# Min: 0.6732, Max: 0.7670
# Anomalie rilevate nei canali: [53 60 61]
#
# --- Analisi MSE ---
# Media: 0.9310, Mediana: 0.9309
# Min: 0.7740, Max: 1.0030
# Anomalie rilevate nei canali: [51 53 61]
#
# --- Analisi RMSE ---
# Media: 0.9648, Mediana: 0.9648
# Min: 0.8798, Max: 1.0015
# Anomalie rilevate nei canali: [51 53 61]
