# %%
# !bash train_WPMixer_B101_48.sh
# Out:
# ========================================
# Avvio training per il modello: WPMixer con finestra48
# ========================================
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           B101_48_48          Model:              WPMixer
#
# Data Loader
#   Data:               custom              Root Path:          ../data/final/
#   Data Path:          B101_50khz_downsampled_reduced.csvFeatures:           M
#   Target:             Channel35           Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            48                  Label Len:          24
#   Pred Len:           48                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             62                  Dec In:             62
#   C Out:              62                  d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               2048
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       10                  Batch Size:         64
#   Patience:           3                   Learning Rate:      0.001
#   Des:                forecasting_48      Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_B101_48_48_WPMixer_custom_ftM_sl48_ll24_pl48_dm256_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_forecasting_48_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 195905
# val 27953
# test 55953
# 	iters: 100, epoch: 1 | loss: 1.1256630
# 	speed: 0.2296s/iter; left time: 7006.7034s
# 	iters: 200, epoch: 1 | loss: 1.0919744
# 	speed: 0.1791s/iter; left time: 5449.6715s
# 	iters: 300, epoch: 1 | loss: 1.1202171
# 	speed: 0.1788s/iter; left time: 5421.2501s
# 	iters: 400, epoch: 1 | loss: 1.0585687
# 	speed: 0.1791s/iter; left time: 5412.8731s
# 	iters: 500, epoch: 1 | loss: 1.0987166
# 	speed: 0.1799s/iter; left time: 5418.6875s
# 	iters: 600, epoch: 1 | loss: 1.0940313
# 	speed: 0.1798s/iter; left time: 5398.1684s
# 	iters: 700, epoch: 1 | loss: 1.0611136
# 	speed: 0.1868s/iter; left time: 5589.8930s
# 	iters: 800, epoch: 1 | loss: 1.0483239
# 	speed: 0.1803s/iter; left time: 5376.4823s
# 	iters: 900, epoch: 1 | loss: 1.0286548
# 	speed: 0.1803s/iter; left time: 5357.8979s
# 	iters: 1000, epoch: 1 | loss: 1.0583858
# 	speed: 0.1806s/iter; left time: 5348.1580s
# 	iters: 1100, epoch: 1 | loss: 1.0001187
# 	speed: 0.1802s/iter; left time: 5319.9507s
# 	iters: 1200, epoch: 1 | loss: 1.0252957
# 	speed: 0.1802s/iter; left time: 5300.5796s
# 	iters: 1300, epoch: 1 | loss: 1.0746279
# 	speed: 0.1850s/iter; left time: 5425.0540s
# 	iters: 1400, epoch: 1 | loss: 1.0958101
# 	speed: 0.1820s/iter; left time: 5317.5000s
# 	iters: 1500, epoch: 1 | loss: 1.0659804
# 	speed: 0.1835s/iter; left time: 5344.4570s
# 	iters: 1600, epoch: 1 | loss: 1.0930243
# 	speed: 0.1809s/iter; left time: 5249.4452s
# 	iters: 1700, epoch: 1 | loss: 1.0528523
# 	speed: 0.1830s/iter; left time: 5293.2545s
# 	iters: 1800, epoch: 1 | loss: 1.0841690
# 	speed: 0.1834s/iter; left time: 5286.9062s
# 	iters: 1900, epoch: 1 | loss: 1.0024065
# 	speed: 0.1877s/iter; left time: 5392.2822s
# 	iters: 2000, epoch: 1 | loss: 1.0327350
# 	speed: 0.1821s/iter; left time: 5212.3843s
# 	iters: 2100, epoch: 1 | loss: 1.1012944
# 	speed: 0.1865s/iter; left time: 5320.3043s
# 	iters: 2200, epoch: 1 | loss: 1.0557098
# 	speed: 0.1865s/iter; left time: 5301.6477s
# 	iters: 2300, epoch: 1 | loss: 1.0193897
# 	speed: 0.1834s/iter; left time: 5194.9407s
# 	iters: 2400, epoch: 1 | loss: 1.0246582
# 	speed: 0.1890s/iter; left time: 5332.4905s
# 	iters: 2500, epoch: 1 | loss: 1.1132265
# 	speed: 0.1860s/iter; left time: 5229.7887s
# 	iters: 2600, epoch: 1 | loss: 1.0415127
# 	speed: 0.1870s/iter; left time: 5238.7791s
# 	iters: 2700, epoch: 1 | loss: 1.0012692
# 	speed: 0.1833s/iter; left time: 5118.6759s
# 	iters: 2800, epoch: 1 | loss: 1.0481622
# 	speed: 0.1809s/iter; left time: 5032.9624s
# 	iters: 2900, epoch: 1 | loss: 1.0452379
# 	speed: 0.1825s/iter; left time: 5060.4289s
# 	iters: 3000, epoch: 1 | loss: 1.0210775
# 	speed: 0.1831s/iter; left time: 5056.2472s
# Epoch: 1 cost time: 564.2380027770996
# Epoch: 1, Steps: 3062 | Train Loss: 1.0650332 Vali Loss: 1.0295209 Test Loss: 1.0109375
# Validation loss decreased (inf --> 1.029521).  Saving model ...
# Updating learning rate to 0.001
# 	iters: 100, epoch: 2 | loss: 1.0567937
# 	speed: 1.1368s/iter; left time: 31216.7246s
# 	iters: 200, epoch: 2 | loss: 1.0601414
# 	speed: 0.1809s/iter; left time: 4948.1928s
# 	iters: 300, epoch: 2 | loss: 1.0924222
# 	speed: 0.1808s/iter; left time: 4927.7296s
# 	iters: 400, epoch: 2 | loss: 1.1191005
# 	speed: 0.1807s/iter; left time: 4906.9193s
# 	iters: 500, epoch: 2 | loss: 1.0910940
# 	speed: 0.1807s/iter; left time: 4889.3826s
# 	iters: 600, epoch: 2 | loss: 1.0531783
# 	speed: 0.1808s/iter; left time: 4874.1349s
# 	iters: 700, epoch: 2 | loss: 1.1390940
# 	speed: 0.1811s/iter; left time: 4863.3964s
# 	iters: 800, epoch: 2 | loss: 1.0576580
# 	speed: 0.1808s/iter; left time: 4838.2464s
# 	iters: 900, epoch: 2 | loss: 1.0275874
# 	speed: 0.1809s/iter; left time: 4822.2487s
# 	iters: 1000, epoch: 2 | loss: 1.0577544
# 	speed: 0.1809s/iter; left time: 4804.7908s
# 	iters: 1100, epoch: 2 | loss: 1.0534501
# 	speed: 0.1810s/iter; left time: 4788.2394s
# 	iters: 1200, epoch: 2 | loss: 1.0773996
# 	speed: 0.1810s/iter; left time: 4772.2217s
# 	iters: 1300, epoch: 2 | loss: 1.0838635
# 	speed: 0.1861s/iter; left time: 4886.1455s
# 	iters: 1400, epoch: 2 | loss: 1.0682209
# 	speed: 0.1843s/iter; left time: 4821.5261s
# 	iters: 1500, epoch: 2 | loss: 1.0082523
# 	speed: 0.1808s/iter; left time: 4712.3886s
# 	iters: 1600, epoch: 2 | loss: 1.0414149
# 	speed: 0.1807s/iter; left time: 4691.5862s
# 	iters: 1700, epoch: 2 | loss: 1.0493814
# 	speed: 0.1805s/iter; left time: 4668.7529s
# 	iters: 1800, epoch: 2 | loss: 1.0649893
# 	speed: 0.1807s/iter; left time: 4654.5612s
# 	iters: 1900, epoch: 2 | loss: 1.0420836
# 	speed: 0.1806s/iter; left time: 4633.2963s
# 	iters: 2000, epoch: 2 | loss: 1.0305698
# 	speed: 0.1805s/iter; left time: 4613.0465s
# 	iters: 2100, epoch: 2 | loss: 1.0517815
# 	speed: 0.1805s/iter; left time: 4594.9851s
# 	iters: 2200, epoch: 2 | loss: 1.1083493
# 	speed: 0.1806s/iter; left time: 4578.7138s
# 	iters: 2300, epoch: 2 | loss: 1.0554599
# 	speed: 0.1805s/iter; left time: 4559.3368s
# 	iters: 2400, epoch: 2 | loss: 1.0364962
# 	speed: 0.1806s/iter; left time: 4543.3817s
# 	iters: 2500, epoch: 2 | loss: 1.0417726
# 	speed: 0.1806s/iter; left time: 4525.0947s
# 	iters: 2600, epoch: 2 | loss: 1.1154468
# 	speed: 0.1808s/iter; left time: 4511.8761s
# 	iters: 2700, epoch: 2 | loss: 1.0902091
# 	speed: 0.1811s/iter; left time: 4501.0846s
# 	iters: 2800, epoch: 2 | loss: 1.0449301
# 	speed: 0.1808s/iter; left time: 4477.4510s
# 	iters: 2900, epoch: 2 | loss: 1.0260948
# 	speed: 0.1808s/iter; left time: 4457.2840s
# 	iters: 3000, epoch: 2 | loss: 1.0392638
# 	speed: 0.1809s/iter; left time: 4442.6047s
# Epoch: 2 cost time: 554.2349855899811
# Epoch: 2, Steps: 3062 | Train Loss: 1.0598849 Vali Loss: 1.0290426 Test Loss: 1.0104163
# Validation loss decreased (1.029521 --> 1.029043).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 3 | loss: 1.0042416
# 	speed: 1.1343s/iter; left time: 27674.4711s
# 	iters: 200, epoch: 3 | loss: 1.0770917
# 	speed: 0.1805s/iter; left time: 4386.3606s
# 	iters: 300, epoch: 3 | loss: 1.0777055
# 	speed: 0.1849s/iter; left time: 4472.8283s
# 	iters: 400, epoch: 3 | loss: 1.0715399
# 	speed: 0.1827s/iter; left time: 4401.5138s
# 	iters: 500, epoch: 3 | loss: 1.0974928
# 	speed: 0.1828s/iter; left time: 4385.5424s
# 	iters: 600, epoch: 3 | loss: 1.0034041
# 	speed: 0.1830s/iter; left time: 4373.5858s
# 	iters: 700, epoch: 3 | loss: 1.0637481
# 	speed: 0.1815s/iter; left time: 4318.9087s
# 	iters: 800, epoch: 3 | loss: 1.0397869
# 	speed: 0.1830s/iter; left time: 4336.4013s
# 	iters: 900, epoch: 3 | loss: 1.0681082
# 	speed: 0.1822s/iter; left time: 4299.0546s
# 	iters: 1000, epoch: 3 | loss: 1.0771549
# 	speed: 0.1904s/iter; left time: 4474.7850s
# 	iters: 1100, epoch: 3 | loss: 1.0985081
# 	speed: 0.1992s/iter; left time: 4660.1943s
# 	iters: 1200, epoch: 3 | loss: 1.0983679
# 	speed: 0.2407s/iter; left time: 5606.6375s
# 	iters: 1300, epoch: 3 | loss: 1.0329934
# 	speed: 0.1812s/iter; left time: 4202.4040s
# 	iters: 1400, epoch: 3 | loss: 1.0540279
# 	speed: 0.2702s/iter; left time: 6241.5492s
# 	iters: 1500, epoch: 3 | loss: 1.0778908
# 	speed: 0.1994s/iter; left time: 4586.6427s
# 	iters: 1600, epoch: 3 | loss: 1.0428631
# 	speed: 0.1874s/iter; left time: 4290.1291s
# 	iters: 1700, epoch: 3 | loss: 1.0714244
# 	speed: 0.1821s/iter; left time: 4151.0712s
# 	iters: 1800, epoch: 3 | loss: 1.0975422
# 	speed: 0.1800s/iter; left time: 4084.6524s
# 	iters: 1900, epoch: 3 | loss: 1.0892338
# 	speed: 0.1800s/iter; left time: 4068.5818s
# 	iters: 2000, epoch: 3 | loss: 1.0736890
# 	speed: 0.1801s/iter; left time: 4052.5241s
# 	iters: 2100, epoch: 3 | loss: 1.0267003
# 	speed: 0.1800s/iter; left time: 4031.8525s
# 	iters: 2200, epoch: 3 | loss: 0.9988877
# 	speed: 0.1810s/iter; left time: 4034.8172s
# 	iters: 2300, epoch: 3 | loss: 0.9992996
# 	speed: 0.1810s/iter; left time: 4016.7051s
# 	iters: 2400, epoch: 3 | loss: 1.0679533
# 	speed: 0.1810s/iter; left time: 4000.3318s
# 	iters: 2500, epoch: 3 | loss: 1.0518625
# 	speed: 0.1809s/iter; left time: 3979.6650s
# 	iters: 2600, epoch: 3 | loss: 1.0815266
# 	speed: 0.1809s/iter; left time: 3961.6089s
# 	iters: 2700, epoch: 3 | loss: 1.0503892
# 	speed: 0.1809s/iter; left time: 3942.6298s
# 	iters: 2800, epoch: 3 | loss: 1.1244035
# 	speed: 0.1809s/iter; left time: 3924.1211s
# 	iters: 2900, epoch: 3 | loss: 1.0397569
# 	speed: 0.1808s/iter; left time: 3904.4674s
# 	iters: 3000, epoch: 3 | loss: 1.0132564
# 	speed: 0.1810s/iter; left time: 3890.2492s
# Epoch: 3 cost time: 575.0804858207703
# Epoch: 3, Steps: 3062 | Train Loss: 1.0586710 Vali Loss: 1.0270355 Test Loss: 1.0084105
# Validation loss decreased (1.029043 --> 1.027035).  Saving model ...
# Updating learning rate to 0.00025
# 	iters: 100, epoch: 4 | loss: 1.0736469
# 	speed: 1.1558s/iter; left time: 24658.4018s
# 	iters: 200, epoch: 4 | loss: 1.0141387
# 	speed: 0.1855s/iter; left time: 3938.8956s
# 	iters: 300, epoch: 4 | loss: 1.0774517
# 	speed: 0.1832s/iter; left time: 3871.0936s
# 	iters: 400, epoch: 4 | loss: 1.0507275
# 	speed: 0.1823s/iter; left time: 3834.3553s
# 	iters: 500, epoch: 4 | loss: 1.0550894
# 	speed: 0.1827s/iter; left time: 3823.8006s
# 	iters: 600, epoch: 4 | loss: 1.0491843
# 	speed: 0.1825s/iter; left time: 3803.2952s
# 	iters: 700, epoch: 4 | loss: 1.0567214
# 	speed: 0.1808s/iter; left time: 3749.7772s
# 	iters: 800, epoch: 4 | loss: 1.0442744
# 	speed: 0.1809s/iter; left time: 3733.2078s
# 	iters: 900, epoch: 4 | loss: 1.0516977
# 	speed: 0.1809s/iter; left time: 3714.1042s
# 	iters: 1000, epoch: 4 | loss: 0.9752408
# 	speed: 0.1809s/iter; left time: 3696.4776s
# 	iters: 1100, epoch: 4 | loss: 1.0136281
# 	speed: 0.1819s/iter; left time: 3698.5994s
# 	iters: 1200, epoch: 4 | loss: 1.0449462
# 	speed: 0.1836s/iter; left time: 3714.5441s
# 	iters: 1300, epoch: 4 | loss: 1.0114338
# 	speed: 0.1833s/iter; left time: 3690.3223s
# 	iters: 1400, epoch: 4 | loss: 1.0311427
# 	speed: 0.1886s/iter; left time: 3779.4659s
# 	iters: 1500, epoch: 4 | loss: 1.0937314
# 	speed: 0.1859s/iter; left time: 3705.5854s
# 	iters: 1600, epoch: 4 | loss: 1.0536306
# 	speed: 0.1850s/iter; left time: 3669.3689s
# 	iters: 1700, epoch: 4 | loss: 1.0655416
# 	speed: 0.1811s/iter; left time: 3574.2681s
# 	iters: 1800, epoch: 4 | loss: 1.0946027
# 	speed: 0.1811s/iter; left time: 3556.3179s
# 	iters: 1900, epoch: 4 | loss: 1.0185456
# 	speed: 0.1810s/iter; left time: 3535.4199s
# 	iters: 2000, epoch: 4 | loss: 1.0957263
# 	speed: 0.1849s/iter; left time: 3592.7491s
# 	iters: 2100, epoch: 4 | loss: 1.0630250
# 	speed: 0.1864s/iter; left time: 3604.6931s
# 	iters: 2200, epoch: 4 | loss: 1.0829519
# 	speed: 0.1798s/iter; left time: 3459.3443s
# 	iters: 2300, epoch: 4 | loss: 1.0853539
# 	speed: 0.1788s/iter; left time: 3421.7341s
# 	iters: 2400, epoch: 4 | loss: 1.0322043
# 	speed: 0.1792s/iter; left time: 3410.6926s
# 	iters: 2500, epoch: 4 | loss: 1.1209918
# 	speed: 0.1804s/iter; left time: 3416.5791s
# 	iters: 2600, epoch: 4 | loss: 1.0093811
# 	speed: 0.1796s/iter; left time: 3382.9501s
# 	iters: 2700, epoch: 4 | loss: 1.0007968
# 	speed: 0.1795s/iter; left time: 3363.7894s
# 	iters: 2800, epoch: 4 | loss: 1.0705365
# 	speed: 0.1798s/iter; left time: 3350.7988s
# 	iters: 2900, epoch: 4 | loss: 1.0690562
# 	speed: 0.1798s/iter; left time: 3332.6259s
# 	iters: 3000, epoch: 4 | loss: 1.0405504
# 	speed: 0.1788s/iter; left time: 3296.8257s
# Epoch: 4 cost time: 557.390510559082
# Epoch: 4, Steps: 3062 | Train Loss: 1.0580267 Vali Loss: 1.0268029 Test Loss: 1.0080048
# Validation loss decreased (1.027035 --> 1.026803).  Saving model ...
# Updating learning rate to 0.000125
# 	iters: 100, epoch: 5 | loss: 1.0368619
# 	speed: 1.1315s/iter; left time: 20675.2358s
# 	iters: 200, epoch: 5 | loss: 1.0323118
# 	speed: 0.1793s/iter; left time: 3257.5531s
# 	iters: 300, epoch: 5 | loss: 1.0758005
# 	speed: 0.1800s/iter; left time: 3252.9626s
# 	iters: 400, epoch: 5 | loss: 1.0809442
# 	speed: 0.1803s/iter; left time: 3240.5865s
# 	iters: 500, epoch: 5 | loss: 1.0757407
# 	speed: 0.1796s/iter; left time: 3210.8645s
# 	iters: 600, epoch: 5 | loss: 1.0522127
# 	speed: 0.1810s/iter; left time: 3217.1579s
# 	iters: 700, epoch: 5 | loss: 0.9721278
# 	speed: 0.1795s/iter; left time: 3172.6522s
# 	iters: 800, epoch: 5 | loss: 1.0776242
# 	speed: 0.1802s/iter; left time: 3167.3763s
# 	iters: 900, epoch: 5 | loss: 1.1180969
# 	speed: 0.1801s/iter; left time: 3147.3196s
# 	iters: 1000, epoch: 5 | loss: 1.0554250
# 	speed: 0.1801s/iter; left time: 3129.2379s
# 	iters: 1100, epoch: 5 | loss: 1.1266892
# 	speed: 0.1798s/iter; left time: 3105.7319s
# 	iters: 1200, epoch: 5 | loss: 1.0150867
# 	speed: 0.1799s/iter; left time: 3089.7777s
# 	iters: 1300, epoch: 5 | loss: 1.0651973
# 	speed: 0.1800s/iter; left time: 3072.5192s
# 	iters: 1400, epoch: 5 | loss: 1.0160611
# 	speed: 0.1793s/iter; left time: 3042.9752s
# 	iters: 1500, epoch: 5 | loss: 1.0432730
# 	speed: 0.1788s/iter; left time: 3017.6219s
# 	iters: 1600, epoch: 5 | loss: 1.1334398
# 	speed: 0.1792s/iter; left time: 3006.4468s
# 	iters: 1700, epoch: 5 | loss: 1.0882778
# 	speed: 0.1799s/iter; left time: 2999.2181s
# 	iters: 1800, epoch: 5 | loss: 1.1028835
# 	speed: 0.1794s/iter; left time: 2973.8237s
# 	iters: 1900, epoch: 5 | loss: 1.1234239
# 	speed: 0.1799s/iter; left time: 2964.0426s
# 	iters: 2000, epoch: 5 | loss: 1.0683823
# 	speed: 0.1795s/iter; left time: 2939.1186s
# 	iters: 2100, epoch: 5 | loss: 0.9960854
# 	speed: 0.1795s/iter; left time: 2920.8379s
# 	iters: 2200, epoch: 5 | loss: 1.0513484
# 	speed: 0.1789s/iter; left time: 2893.8805s
# 	iters: 2300, epoch: 5 | loss: 1.0066411
# 	speed: 0.1779s/iter; left time: 2859.9856s
# 	iters: 2400, epoch: 5 | loss: 1.1099626
# 	speed: 0.1782s/iter; left time: 2846.8321s
# 	iters: 2500, epoch: 5 | loss: 1.1062764
# 	speed: 0.1790s/iter; left time: 2841.0744s
# 	iters: 2600, epoch: 5 | loss: 1.0327592
# 	speed: 0.1790s/iter; left time: 2823.7270s
# 	iters: 2700, epoch: 5 | loss: 1.0347215
# 	speed: 0.1800s/iter; left time: 2821.5332s
# 	iters: 2800, epoch: 5 | loss: 1.0262365
# 	speed: 0.1792s/iter; left time: 2789.9306s
# 	iters: 2900, epoch: 5 | loss: 1.0697749
# 	speed: 0.1808s/iter; left time: 2797.4375s
# 	iters: 3000, epoch: 5 | loss: 1.0418310
# 	speed: 0.1809s/iter; left time: 2780.7999s
# Epoch: 5 cost time: 549.9572334289551
# Epoch: 5, Steps: 3062 | Train Loss: 1.0577267 Vali Loss: 1.0267129 Test Loss: 1.0080248
# Validation loss decreased (1.026803 --> 1.026713).  Saving model ...
# Updating learning rate to 6.25e-05
# 	iters: 100, epoch: 6 | loss: 1.0536257
# 	speed: 1.1368s/iter; left time: 17291.6445s
# 	iters: 200, epoch: 6 | loss: 1.0646008
# 	speed: 0.1809s/iter; left time: 2732.8271s
# 	iters: 300, epoch: 6 | loss: 1.0968336
# 	speed: 0.1810s/iter; left time: 2717.5748s
# 	iters: 400, epoch: 6 | loss: 1.0166799
# 	speed: 0.1808s/iter; left time: 2695.7589s
# 	iters: 500, epoch: 6 | loss: 1.0178391
# 	speed: 0.1807s/iter; left time: 2676.6357s
# 	iters: 600, epoch: 6 | loss: 1.0776320
# 	speed: 0.1807s/iter; left time: 2658.8395s
# 	iters: 700, epoch: 6 | loss: 1.1179850
# 	speed: 0.1813s/iter; left time: 2648.3524s
# 	iters: 800, epoch: 6 | loss: 1.0536237
# 	speed: 0.1804s/iter; left time: 2617.5626s
# 	iters: 900, epoch: 6 | loss: 1.1208382
# 	speed: 0.1807s/iter; left time: 2604.6896s
# 	iters: 1000, epoch: 6 | loss: 1.0303857
# 	speed: 0.1809s/iter; left time: 2588.2300s
# 	iters: 1100, epoch: 6 | loss: 1.0752649
# 	speed: 0.1810s/iter; left time: 2571.5214s
# 	iters: 1200, epoch: 6 | loss: 1.0512960
# 	speed: 0.1806s/iter; left time: 2548.5133s
# 	iters: 1300, epoch: 6 | loss: 1.0464653
# 	speed: 0.1809s/iter; left time: 2534.0396s
# 	iters: 1400, epoch: 6 | loss: 1.0468801
# 	speed: 0.1806s/iter; left time: 2512.4349s
# 	iters: 1500, epoch: 6 | loss: 1.0999020
# 	speed: 0.1805s/iter; left time: 2492.7482s
# 	iters: 1600, epoch: 6 | loss: 1.0917150
# 	speed: 0.1806s/iter; left time: 2476.7905s
# 	iters: 1700, epoch: 6 | loss: 1.1205330
# 	speed: 0.1809s/iter; left time: 2462.5207s
# 	iters: 1800, epoch: 6 | loss: 1.0338068
# 	speed: 0.1808s/iter; left time: 2442.7076s
# 	iters: 1900, epoch: 6 | loss: 1.0372236
# 	speed: 0.1814s/iter; left time: 2432.8961s
# 	iters: 2000, epoch: 6 | loss: 1.0228639
# 	speed: 0.1813s/iter; left time: 2413.5269s
# 	iters: 2100, epoch: 6 | loss: 0.9890545
# 	speed: 0.1810s/iter; left time: 2390.8763s
# 	iters: 2200, epoch: 6 | loss: 1.0527602
# 	speed: 0.1807s/iter; left time: 2368.9172s
# 	iters: 2300, epoch: 6 | loss: 1.0759869
# 	speed: 0.1809s/iter; left time: 2353.1881s
# 	iters: 2400, epoch: 6 | loss: 1.0406796
# 	speed: 0.1810s/iter; left time: 2336.6801s
# 	iters: 2500, epoch: 6 | loss: 1.0896412
# 	speed: 0.1805s/iter; left time: 2312.5004s
# 	iters: 2600, epoch: 6 | loss: 1.0518671
# 	speed: 0.1806s/iter; left time: 2295.9878s
# 	iters: 2700, epoch: 6 | loss: 1.0169743
# 	speed: 0.1807s/iter; left time: 2278.2861s
# 	iters: 2800, epoch: 6 | loss: 1.0966942
# 	speed: 0.1805s/iter; left time: 2258.0138s
# 	iters: 2900, epoch: 6 | loss: 1.0418290
# 	speed: 0.1807s/iter; left time: 2242.7529s
# 	iters: 3000, epoch: 6 | loss: 1.0641828
# 	speed: 0.1805s/iter; left time: 2222.1550s
# Epoch: 6 cost time: 553.401163816452
# Epoch: 6, Steps: 3062 | Train Loss: 1.0575008 Vali Loss: 1.0268085 Test Loss: 1.0081072
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-05
# 	iters: 100, epoch: 7 | loss: 1.0656393
# 	speed: 1.1324s/iter; left time: 13757.8496s
# 	iters: 200, epoch: 7 | loss: 1.0262520
# 	speed: 0.1805s/iter; left time: 2175.4285s
# 	iters: 300, epoch: 7 | loss: 1.0849968
# 	speed: 0.1804s/iter; left time: 2155.1449s
# 	iters: 400, epoch: 7 | loss: 1.0411406
# 	speed: 0.1807s/iter; left time: 2141.0617s
# 	iters: 500, epoch: 7 | loss: 1.0517583
# 	speed: 0.1824s/iter; left time: 2142.7360s
# 	iters: 600, epoch: 7 | loss: 1.0058045
# 	speed: 0.1851s/iter; left time: 2155.9308s
# 	iters: 700, epoch: 7 | loss: 1.0574495
# 	speed: 0.1845s/iter; left time: 2130.6547s
# 	iters: 800, epoch: 7 | loss: 1.0399600
# 	speed: 0.1830s/iter; left time: 2095.0277s
# 	iters: 900, epoch: 7 | loss: 1.0743672
# 	speed: 0.1827s/iter; left time: 2073.3736s
# 	iters: 1000, epoch: 7 | loss: 1.0227047
# 	speed: 0.1843s/iter; left time: 2073.2650s
# 	iters: 1100, epoch: 7 | loss: 1.1186322
# 	speed: 0.1856s/iter; left time: 2068.7748s
# 	iters: 1200, epoch: 7 | loss: 1.0551791
# 	speed: 0.1853s/iter; left time: 2047.1557s
# 	iters: 1300, epoch: 7 | loss: 0.9601388
# 	speed: 0.1819s/iter; left time: 1991.8241s
# 	iters: 1400, epoch: 7 | loss: 1.0592356
# 	speed: 0.1808s/iter; left time: 1961.8455s
# 	iters: 1500, epoch: 7 | loss: 1.0530087
# 	speed: 0.1817s/iter; left time: 1953.5455s
# 	iters: 1600, epoch: 7 | loss: 1.0607861
# 	speed: 0.1825s/iter; left time: 1943.0771s
# 	iters: 1700, epoch: 7 | loss: 0.9723373
# 	speed: 0.1817s/iter; left time: 1917.0952s
# 	iters: 1800, epoch: 7 | loss: 1.0305308
# 	speed: 0.1808s/iter; left time: 1889.4730s
# 	iters: 1900, epoch: 7 | loss: 1.0597541
# 	speed: 0.1820s/iter; left time: 1883.5236s
# 	iters: 2000, epoch: 7 | loss: 1.0685537
# 	speed: 0.1824s/iter; left time: 1869.4011s
# 	iters: 2100, epoch: 7 | loss: 0.9833277
# 	speed: 0.1812s/iter; left time: 1839.3097s
# 	iters: 2200, epoch: 7 | loss: 1.0659144
# 	speed: 0.1819s/iter; left time: 1827.5367s
# 	iters: 2300, epoch: 7 | loss: 1.0449536
# 	speed: 0.1827s/iter; left time: 1817.5784s
# 	iters: 2400, epoch: 7 | loss: 1.0221276
# 	speed: 0.1811s/iter; left time: 1783.2355s
# 	iters: 2500, epoch: 7 | loss: 1.0779599
# 	speed: 0.1809s/iter; left time: 1763.5738s
# 	iters: 2600, epoch: 7 | loss: 1.0596187
# 	speed: 0.1809s/iter; left time: 1745.1545s
# 	iters: 2700, epoch: 7 | loss: 1.0268364
# 	speed: 0.1818s/iter; left time: 1735.6691s
# 	iters: 2800, epoch: 7 | loss: 1.0617833
# 	speed: 0.1838s/iter; left time: 1736.3749s
# 	iters: 2900, epoch: 7 | loss: 1.0180681
# 	speed: 0.1791s/iter; left time: 1674.6560s
# 	iters: 3000, epoch: 7 | loss: 1.0619582
# 	speed: 0.1818s/iter; left time: 1681.3071s
# Epoch: 7 cost time: 557.4017498493195
# Epoch: 7, Steps: 3062 | Train Loss: 1.0571400 Vali Loss: 1.0266595 Test Loss: 1.0079449
# Validation loss decreased (1.026713 --> 1.026659).  Saving model ...
# Updating learning rate to 1.5625e-05
# 	iters: 100, epoch: 8 | loss: 1.0555165
# 	speed: 1.1224s/iter; left time: 10199.3792s
# 	iters: 200, epoch: 8 | loss: 1.0747714
# 	speed: 0.1782s/iter; left time: 1601.1969s
# 	iters: 300, epoch: 8 | loss: 1.0624162
# 	speed: 0.1780s/iter; left time: 1581.8969s
# 	iters: 400, epoch: 8 | loss: 1.0261116
# 	speed: 0.1781s/iter; left time: 1564.6688s
# 	iters: 500, epoch: 8 | loss: 1.1403816
# 	speed: 0.1783s/iter; left time: 1548.6029s
# 	iters: 600, epoch: 8 | loss: 1.1101612
# 	speed: 0.1781s/iter; left time: 1529.5243s
# 	iters: 700, epoch: 8 | loss: 1.0492524
# 	speed: 0.1839s/iter; left time: 1560.8359s
# 	iters: 800, epoch: 8 | loss: 1.0589507
# 	speed: 0.1824s/iter; left time: 1529.7352s
# 	iters: 900, epoch: 8 | loss: 1.0846816
# 	speed: 0.1792s/iter; left time: 1485.0350s
# 	iters: 1000, epoch: 8 | loss: 1.0073296
# 	speed: 0.1793s/iter; left time: 1467.9877s
# 	iters: 1100, epoch: 8 | loss: 1.0252848
# 	speed: 0.1807s/iter; left time: 1461.3757s
# 	iters: 1200, epoch: 8 | loss: 1.0780919
# 	speed: 0.1800s/iter; left time: 1437.9076s
# 	iters: 1300, epoch: 8 | loss: 1.0792049
# 	speed: 0.1812s/iter; left time: 1429.3673s
# 	iters: 1400, epoch: 8 | loss: 1.0192922
# 	speed: 0.1838s/iter; left time: 1431.4303s
# 	iters: 1500, epoch: 8 | loss: 1.1035253
# 	speed: 0.1836s/iter; left time: 1411.3965s
# 	iters: 1600, epoch: 8 | loss: 1.1244050
# 	speed: 0.1851s/iter; left time: 1404.1774s
# 	iters: 1700, epoch: 8 | loss: 1.1043663
# 	speed: 0.1856s/iter; left time: 1389.8286s
# 	iters: 1800, epoch: 8 | loss: 1.0374987
# 	speed: 0.1802s/iter; left time: 1331.4222s
# 	iters: 1900, epoch: 8 | loss: 0.9965602
# 	speed: 0.1826s/iter; left time: 1330.3758s
# 	iters: 2000, epoch: 8 | loss: 1.0414988
# 	speed: 0.1793s/iter; left time: 1288.3558s
# 	iters: 2100, epoch: 8 | loss: 1.1187639
# 	speed: 0.1796s/iter; left time: 1272.5601s
# 	iters: 2200, epoch: 8 | loss: 1.0156814
# 	speed: 0.1807s/iter; left time: 1262.2443s
# 	iters: 2300, epoch: 8 | loss: 1.0581138
# 	speed: 0.1785s/iter; left time: 1229.1585s
# 	iters: 2400, epoch: 8 | loss: 1.0965514
# 	speed: 0.1787s/iter; left time: 1213.1509s
# 	iters: 2500, epoch: 8 | loss: 1.0534909
# 	speed: 0.1785s/iter; left time: 1193.8552s
# 	iters: 2600, epoch: 8 | loss: 1.1091677
# 	speed: 0.1784s/iter; left time: 1175.3992s
# 	iters: 2700, epoch: 8 | loss: 0.9967051
# 	speed: 0.1784s/iter; left time: 1157.3631s
# 	iters: 2800, epoch: 8 | loss: 1.0318964
# 	speed: 0.1784s/iter; left time: 1139.3064s
# 	iters: 2900, epoch: 8 | loss: 1.0330309
# 	speed: 0.1783s/iter; left time: 1121.2623s
# 	iters: 3000, epoch: 8 | loss: 1.0600284
# 	speed: 0.1786s/iter; left time: 1104.9173s
# Epoch: 8 cost time: 551.286878824234
# Epoch: 8, Steps: 3062 | Train Loss: 1.0572668 Vali Loss: 1.0266141 Test Loss: 1.0078946
# Validation loss decreased (1.026659 --> 1.026614).  Saving model ...
# Updating learning rate to 7.8125e-06
# 	iters: 100, epoch: 9 | loss: 1.0827901
# 	speed: 1.1197s/iter; left time: 6746.4572s
# 	iters: 200, epoch: 9 | loss: 0.9954650
# 	speed: 0.1784s/iter; left time: 1057.0176s
# 	iters: 300, epoch: 9 | loss: 0.9939368
# 	speed: 0.1805s/iter; left time: 1051.3249s
# 	iters: 400, epoch: 9 | loss: 1.0514561
# 	speed: 0.1828s/iter; left time: 1046.7816s
# 	iters: 500, epoch: 9 | loss: 1.0796781
# 	speed: 0.1873s/iter; left time: 1053.7347s
# 	iters: 600, epoch: 9 | loss: 1.1327603
# 	speed: 0.1828s/iter; left time: 1010.0119s
# 	iters: 700, epoch: 9 | loss: 1.0324049
# 	speed: 0.1848s/iter; left time: 1002.2730s
# 	iters: 800, epoch: 9 | loss: 1.0338105
# 	speed: 0.1829s/iter; left time: 974.0731s
# 	iters: 900, epoch: 9 | loss: 1.0178193
# 	speed: 0.1866s/iter; left time: 974.8360s
# 	iters: 1000, epoch: 9 | loss: 1.0132147
# 	speed: 0.1853s/iter; left time: 949.8629s
# 	iters: 1100, epoch: 9 | loss: 1.0048196
# 	speed: 0.1848s/iter; left time: 928.4710s
# 	iters: 1200, epoch: 9 | loss: 1.0647526
# 	speed: 0.1820s/iter; left time: 896.2319s
# 	iters: 1300, epoch: 9 | loss: 1.1193818
# 	speed: 0.1829s/iter; left time: 882.3855s
# 	iters: 1400, epoch: 9 | loss: 1.0267282
# 	speed: 0.1840s/iter; left time: 869.4074s
# 	iters: 1500, epoch: 9 | loss: 1.0873449
# 	speed: 0.1820s/iter; left time: 841.5237s
# 	iters: 1600, epoch: 9 | loss: 1.0567898
# 	speed: 0.1820s/iter; left time: 823.7457s
# 	iters: 1700, epoch: 9 | loss: 1.1017962
# 	speed: 0.1815s/iter; left time: 803.3537s
# 	iters: 1800, epoch: 9 | loss: 1.0556117
# 	speed: 0.1816s/iter; left time: 785.2047s
# 	iters: 1900, epoch: 9 | loss: 1.0501947
# 	speed: 0.1814s/iter; left time: 766.2567s
# 	iters: 2000, epoch: 9 | loss: 1.0378541
# 	speed: 0.1817s/iter; left time: 749.6226s
# 	iters: 2100, epoch: 9 | loss: 1.0544277
# 	speed: 0.1819s/iter; left time: 732.2383s
# 	iters: 2200, epoch: 9 | loss: 1.0385773
# 	speed: 0.1818s/iter; left time: 713.4996s
# 	iters: 2300, epoch: 9 | loss: 1.1121703
# 	speed: 0.1825s/iter; left time: 698.0056s
# 	iters: 2400, epoch: 9 | loss: 1.0729842
# 	speed: 0.1816s/iter; left time: 676.5802s
# 	iters: 2500, epoch: 9 | loss: 1.0360831
# 	speed: 0.1834s/iter; left time: 664.7757s
# 	iters: 2600, epoch: 9 | loss: 1.0478504
# 	speed: 0.1793s/iter; left time: 631.9410s
# 	iters: 2700, epoch: 9 | loss: 0.9683909
# 	speed: 0.1791s/iter; left time: 613.2896s
# 	iters: 2800, epoch: 9 | loss: 1.0754751
# 	speed: 0.1835s/iter; left time: 610.0333s
# 	iters: 2900, epoch: 9 | loss: 1.0738969
# 	speed: 0.1805s/iter; left time: 582.0534s
# 	iters: 3000, epoch: 9 | loss: 1.0705712
# 	speed: 0.1792s/iter; left time: 559.8669s
# Epoch: 9 cost time: 557.6543185710907
# Epoch: 9, Steps: 3062 | Train Loss: 1.0569984 Vali Loss: 1.0266684 Test Loss: 1.0079316
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-06
# 	iters: 100, epoch: 10 | loss: 1.1027961
# 	speed: 1.1381s/iter; left time: 3372.1102s
# 	iters: 200, epoch: 10 | loss: 1.0844653
# 	speed: 0.1803s/iter; left time: 516.3258s
# 	iters: 300, epoch: 10 | loss: 1.0953599
# 	speed: 0.1792s/iter; left time: 495.0094s
# 	iters: 400, epoch: 10 | loss: 1.0903125
# 	speed: 0.1787s/iter; left time: 476.0049s
# 	iters: 500, epoch: 10 | loss: 1.0651902
# 	speed: 0.1796s/iter; left time: 460.1947s
# 	iters: 600, epoch: 10 | loss: 1.0941287
# 	speed: 0.1787s/iter; left time: 440.0640s
# 	iters: 700, epoch: 10 | loss: 1.0210350
# 	speed: 0.1790s/iter; left time: 422.9704s
# 	iters: 800, epoch: 10 | loss: 1.1334845
# 	speed: 0.1786s/iter; left time: 404.1203s
# 	iters: 900, epoch: 10 | loss: 1.0833005
# 	speed: 0.1787s/iter; left time: 386.6023s
# 	iters: 1000, epoch: 10 | loss: 1.0666471
# 	speed: 0.1790s/iter; left time: 369.1793s
# 	iters: 1100, epoch: 10 | loss: 1.0612115
# 	speed: 0.1797s/iter; left time: 352.7116s
# 	iters: 1200, epoch: 10 | loss: 1.0629610
# 	speed: 0.1805s/iter; left time: 336.3067s
# 	iters: 1300, epoch: 10 | loss: 1.0337340
# 	speed: 0.1790s/iter; left time: 315.5871s
# 	iters: 1400, epoch: 10 | loss: 1.0990649
# 	speed: 0.1791s/iter; left time: 297.8689s
# 	iters: 1500, epoch: 10 | loss: 1.0385493
# 	speed: 0.1790s/iter; left time: 279.8446s
# 	iters: 1600, epoch: 10 | loss: 1.0350280
# 	speed: 0.1791s/iter; left time: 262.0048s
# 	iters: 1700, epoch: 10 | loss: 1.0808095
# 	speed: 0.1791s/iter; left time: 244.0735s
# 	iters: 1800, epoch: 10 | loss: 1.0122477
# 	speed: 0.1824s/iter; left time: 230.3082s
# 	iters: 1900, epoch: 10 | loss: 1.0959688
# 	speed: 0.1795s/iter; left time: 208.7901s
# 	iters: 2000, epoch: 10 | loss: 1.0478588
# 	speed: 0.1790s/iter; left time: 190.3089s
# 	iters: 2100, epoch: 10 | loss: 1.1016164
# 	speed: 0.1802s/iter; left time: 173.5637s
# 	iters: 2200, epoch: 10 | loss: 1.0976235
# 	speed: 0.1871s/iter; left time: 161.5035s
# 	iters: 2300, epoch: 10 | loss: 1.0338557
# 	speed: 0.1852s/iter; left time: 141.3179s
# 	iters: 2400, epoch: 10 | loss: 1.0358933
# 	speed: 0.1832s/iter; left time: 121.4512s
# 	iters: 2500, epoch: 10 | loss: 1.0426635
# 	speed: 0.1839s/iter; left time: 103.5382s
# 	iters: 2600, epoch: 10 | loss: 1.0767603
# 	speed: 0.1822s/iter; left time: 84.3552s
# 	iters: 2700, epoch: 10 | loss: 1.0735086
# 	speed: 0.1824s/iter; left time: 66.2287s
# 	iters: 2800, epoch: 10 | loss: 1.0291910
# 	speed: 0.1822s/iter; left time: 47.9249s
# 	iters: 2900, epoch: 10 | loss: 1.1177948
# 	speed: 0.1823s/iter; left time: 29.7218s
# 	iters: 3000, epoch: 10 | loss: 1.0238299
# 	speed: 0.1831s/iter; left time: 11.5355s
# Epoch: 10 cost time: 553.3391602039337
# Epoch: 10, Steps: 3062 | Train Loss: 1.0571780 Vali Loss: 1.0266701 Test Loss: 1.0079525
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.953125e-06
# >>>>>>>testing : long_term_forecast_B101_48_48_WPMixer_custom_ftM_sl48_ll24_pl48_dm256_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_forecasting_48_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 55953
# test shape: (55953, 48, 62) (55953, 48, 62)
# test shape: (55953, 48, 62) (55953, 48, 62)
# mse:1.0080006122589111, mae:0.7713106274604797, dtw:Not calculated
# Training completato per WPMixer.

# %%
import numpy as np
import matplotlib.pyplot as plt

# CI HA IMPIEGATO 40 MINUTI

# Sostituisci con il tuo setting o percorso
setting = 'long_term_forecast_B101_48_48_WPMixer_custom_ftM_sl48_ll24_pl48_dm256_nh8_el2_dl1_df2048_expand2_dc4_fc1_ebtimeF_dtTrue_forecasting_48_0'
metrics_path = 'results/' + setting + '/metrics.npy'
pred_path = 'results/' + setting + '/pred.npy'
true_path = 'results/' + setting + '/true.npy'

# Caricamento dei file
metrics = np.load(metrics_path)
preds = np.load(pred_path)
trues = np.load(true_path)

# Stampa delle forme per verifica
print("Shape metrics:", metrics.shape)
print("Shape preds:", preds.shape)
print("Shape trues:", trues.shape)

# Stampa opzionale delle metriche
print("Metrics:\n", metrics)

# Assumiamo che la forma di preds e trues sia (n_samples, L, n_channels)
n_samples, L, n_channels = trues.shape

# Generiamo i nomi dei canali (1..n_channels)
variables = [f'Channel{i}' for i in range(1, n_channels + 1)]

# Seleziona il sample da plottare
idx_sample = 0  # cambia se vuoi visualizzare altri sample

# Plot per ogni variabile (canale)
for i, var_name in enumerate(variables):
    plt.figure(figsize=(8, 5))
    # Ground Truth
    plt.plot(
        trues[idx_sample, :, i],
        label=f'GroundTruth ({var_name})',
        color='blue'
    )
    # Prediction
    plt.plot(
        preds[idx_sample, :, i],
        label=f'Prediction ({var_name})',
        color='orange',
        linestyle='--'
    )
    plt.title(f'Confronto - Variabile: {var_name} (Sample {idx_sample})')
    plt.xlabel('Time Step')
    plt.ylabel(var_name)
    plt.legend()
    plt.show()
# Out:
# Shape metrics: (5,)
# Shape preds: (55953, 48, 62)
# Shape trues: (55953, 48, 62)
# Metrics:
#  [7.7131063e-01 1.0080006e+00 1.0039923e+00 3.1304550e+00 1.1406703e+05]

# %%
# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

for i, var_name in enumerate(variables):
    y_true = trues[:, :, i].flatten()  # Ground truth per la variabile i
    y_pred = preds[:, :, i].flatten()  # Predizioni per la variabile i
    
    print(f"\n--- Metriche per la variabile: {var_name} ---")
    print(f"MAE : {mae(y_true, y_pred):.4f}")
    print(f"MSE : {mse(y_true, y_pred):.4f}")
    print(f"RMSE: {rmse(y_true, y_pred):.4f}")
# Out:
# --- Metriche per la variabile: Channel1 ---
# MAE : 0.7803
# MSE : 1.0188
# RMSE: 1.0094
#
# --- Metriche per la variabile: Channel2 ---
# MAE : 0.7772
# MSE : 1.0121
# RMSE: 1.0060
#
# --- Metriche per la variabile: Channel3 ---
# MAE : 0.7795
# MSE : 1.0152
# RMSE: 1.0076
#
# --- Metriche per la variabile: Channel4 ---
# MAE : 0.7806
# MSE : 1.0188
# RMSE: 1.0094
#
# --- Metriche per la variabile: Channel5 ---
# MAE : 0.7779
# MSE : 1.0150
# RMSE: 1.0075
#
# --- Metriche per la variabile: Channel6 ---
# MAE : 0.7814
# MSE : 1.0228
# RMSE: 1.0114
#
# --- Metriche per la variabile: Channel7 ---
# MAE : 0.7823
# MSE : 1.0254
# RMSE: 1.0126
#
# --- Metriche per la variabile: Channel8 ---
# MAE : 0.7830
# MSE : 1.0262
# RMSE: 1.0130
#
# --- Metriche per la variabile: Channel9 ---
# MAE : 0.7826
# MSE : 1.0202
# RMSE: 1.0101
#
# --- Metriche per la variabile: Channel10 ---
# MAE : 0.7885
# MSE : 1.0348
# RMSE: 1.0173
#
# --- Metriche per la variabile: Channel11 ---
# MAE : 0.7869
# MSE : 1.0291
# RMSE: 1.0144
#
# --- Metriche per la variabile: Channel12 ---
# MAE : 0.7817
# MSE : 1.0238
# RMSE: 1.0118
#
# --- Metriche per la variabile: Channel13 ---
# MAE : 0.7780
# MSE : 1.0119
# RMSE: 1.0059
#
# --- Metriche per la variabile: Channel14 ---
# MAE : 0.7806
# MSE : 1.0144
# RMSE: 1.0072
#
# --- Metriche per la variabile: Channel15 ---
# MAE : 0.7719
# MSE : 1.0012
# RMSE: 1.0006
#
# --- Metriche per la variabile: Channel16 ---
# MAE : 0.7787
# MSE : 1.0111
# RMSE: 1.0055
#
# --- Metriche per la variabile: Channel17 ---
# MAE : 0.7818
# MSE : 1.0191
# RMSE: 1.0095
#
# --- Metriche per la variabile: Channel18 ---
# MAE : 0.7771
# MSE : 1.0110
# RMSE: 1.0055
#
# --- Metriche per la variabile: Channel19 ---
# MAE : 0.7802
# MSE : 1.0187
# RMSE: 1.0093
#
# --- Metriche per la variabile: Channel20 ---
# MAE : 0.7780
# MSE : 1.0173
# RMSE: 1.0086
#
# --- Metriche per la variabile: Channel21 ---
# MAE : 0.7797
# MSE : 1.0169
# RMSE: 1.0084
#
# --- Metriche per la variabile: Channel22 ---
# MAE : 0.7792
# MSE : 1.0165
# RMSE: 1.0082
#
# --- Metriche per la variabile: Channel23 ---
# MAE : 0.7827
# MSE : 1.0207
# RMSE: 1.0103
#
# --- Metriche per la variabile: Channel24 ---
# MAE : 0.7770
# MSE : 1.0148
# RMSE: 1.0074
#
# --- Metriche per la variabile: Channel25 ---
# MAE : 0.7813
# MSE : 1.0203
# RMSE: 1.0101
#
# --- Metriche per la variabile: Channel26 ---
# MAE : 0.7855
# MSE : 1.0283
# RMSE: 1.0141
#
# --- Metriche per la variabile: Channel27 ---
# MAE : 0.7875
# MSE : 1.0372
# RMSE: 1.0184
#
# --- Metriche per la variabile: Channel28 ---
# MAE : 0.7920
# MSE : 1.0492
# RMSE: 1.0243
#
# --- Metriche per la variabile: Channel29 ---
# MAE : 0.7806
# MSE : 1.0186
# RMSE: 1.0092
#
# --- Metriche per la variabile: Channel30 ---
# MAE : 0.7844
# MSE : 1.0283
# RMSE: 1.0141
#
# --- Metriche per la variabile: Channel31 ---
# MAE : 0.7891
# MSE : 1.0436
# RMSE: 1.0216
#
# --- Metriche per la variabile: Channel32 ---
# MAE : 0.7836
# MSE : 1.0315
# RMSE: 1.0156
#
# --- Metriche per la variabile: Channel33 ---
# MAE : 0.7844
# MSE : 1.0278
# RMSE: 1.0138
#
# --- Metriche per la variabile: Channel34 ---
# MAE : 0.7681
# MSE : 0.9909
# RMSE: 0.9954
#
# --- Metriche per la variabile: Channel35 ---
# MAE : 0.7787
# MSE : 1.0148
# RMSE: 1.0074
#
# --- Metriche per la variabile: Channel36 ---
# MAE : 0.7812
# MSE : 1.0233
# RMSE: 1.0116
#
# --- Metriche per la variabile: Channel37 ---
# MAE : 0.7943
# MSE : 1.0415
# RMSE: 1.0205
#
# --- Metriche per la variabile: Channel38 ---
# MAE : 0.7763
# MSE : 1.0078
# RMSE: 1.0039
#
# --- Metriche per la variabile: Channel39 ---
# MAE : 0.7765
# MSE : 1.0086
# RMSE: 1.0043
#
# --- Metriche per la variabile: Channel40 ---
# MAE : 0.7820
# MSE : 1.0268
# RMSE: 1.0133
#
# --- Metriche per la variabile: Channel41 ---
# MAE : 0.7828
# MSE : 1.0292
# RMSE: 1.0145
#
# --- Metriche per la variabile: Channel42 ---
# MAE : 0.7875
# MSE : 1.0376
# RMSE: 1.0186
#
# --- Metriche per la variabile: Channel43 ---
# MAE : 0.7816
# MSE : 1.0285
# RMSE: 1.0142
#
# --- Metriche per la variabile: Channel44 ---
# MAE : 0.7829
# MSE : 1.0285
# RMSE: 1.0142
#
# --- Metriche per la variabile: Channel45 ---
# MAE : 0.7833
# MSE : 1.0291
# RMSE: 1.0145
#
# --- Metriche per la variabile: Channel46 ---
# MAE : 0.7758
# MSE : 1.0078
# RMSE: 1.0039
#
# --- Metriche per la variabile: Channel47 ---
# MAE : 0.7815
# MSE : 1.0215
# RMSE: 1.0107
#
# --- Metriche per la variabile: Channel48 ---
# MAE : 0.7735
# MSE : 1.0084
# RMSE: 1.0042
#
# --- Metriche per la variabile: Channel49 ---
# MAE : 0.7762
# MSE : 1.0192
# RMSE: 1.0096
#
# --- Metriche per la variabile: Channel50 ---
# MAE : 0.7813
# MSE : 1.0250
# RMSE: 1.0124
#
# --- Metriche per la variabile: Channel51 ---
# MAE : 0.7796
# MSE : 1.0242
# RMSE: 1.0120
#
# --- Metriche per la variabile: Channel52 ---
# MAE : 0.7848
# MSE : 1.0284
# RMSE: 1.0141
#
# --- Metriche per la variabile: Channel53 ---
# MAE : 0.7993
# MSE : 1.0777
# RMSE: 1.0381
#
# --- Metriche per la variabile: Channel54 ---
# MAE : 0.7806
# MSE : 1.0189
# RMSE: 1.0094
#
# --- Metriche per la variabile: Channel55 ---
# MAE : 0.7779
# MSE : 1.0139
# RMSE: 1.0069
#
# --- Metriche per la variabile: Channel56 ---
# MAE : 0.7768
# MSE : 1.0154
# RMSE: 1.0077
#
# --- Metriche per la variabile: Channel57 ---
# MAE : 0.7788
# MSE : 1.0223
# RMSE: 1.0111
#
# --- Metriche per la variabile: Channel58 ---
# MAE : 0.7846
# MSE : 1.0266
# RMSE: 1.0132
#
# --- Metriche per la variabile: Channel59 ---
# MAE : 0.7832
# MSE : 1.0201
# RMSE: 1.0100
#
# --- Metriche per la variabile: Channel60 ---
# MAE : 0.8073
# MSE : 1.0764
# RMSE: 1.0375
#
# --- Metriche per la variabile: Channel61 ---
# MAE : 0.1392
# MSE : 0.1104
# RMSE: 0.3323
#
# --- Metriche per la variabile: Channel62 ---
# MAE : 0.7707
# MSE : 0.9927
# RMSE: 0.9963

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# Creazione di una lista per memorizzare le metriche
metrics_data = []

for i, var_name in enumerate(variables):
    y_true = trues[:, :, i].flatten()
    y_pred = preds[:, :, i].flatten()
    
    metrics_data.append([var_name, mae(y_true, y_pred), mse(y_true, y_pred), rmse(y_true, y_pred)])

# Creazione di un DataFrame
df_metrics = pd.DataFrame(metrics_data, columns=['Channel', 'MAE', 'MSE', 'RMSE'])

# Visualizzazione della tabella con matplotlib
fig, ax = plt.subplots(figsize=(8, 10))  # Dimensioni della figura
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_metrics.values, colLabels=df_metrics.columns, cellLoc = 'center', loc='center')

plt.show()

# Salva l'immagine nella cartella dei risultati
output_dir = f'./results/{setting}'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

fig.savefig(os.path.join(output_dir, 'metrics_table.png'))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Funzioni metriche
def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# Calcola metriche per ciascun canale
mae_list, mse_list, rmse_list = [], [], []

for i in range(preds.shape[2]):
    y_true = trues[:, :, i].flatten()
    y_pred = preds[:, :, i].flatten()

    mae_list.append(mae(y_true, y_pred))
    mse_list.append(mse(y_true, y_pred))
    rmse_list.append(rmse(y_true, y_pred))

# Converti in array per analisi
mae_array = np.array(mae_list)
mse_array = np.array(mse_list)
rmse_array = np.array(rmse_list)

# Calcola statistiche
metrics = {'MAE': mae_array, 'MSE': mse_array, 'RMSE': rmse_array}

for metric_name, values in metrics.items():
    print(f"\n--- Analisi {metric_name} ---")
    print(f"Media: {np.mean(values):.4f}, Mediana: {np.median(values):.4f}")
    print(f"Min: {np.min(values):.4f}, Max: {np.max(values):.4f}")

    # Rileva anomalie con IQR
    Q1 = np.percentile(values, 25)
    Q3 = np.percentile(values, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    anomalies = np.where((values < lower_bound) | (values > upper_bound))[0]
    if len(anomalies) > 0:
        print(f"Anomalie rilevate nei canali: {anomalies + 1}")
    else:
        print("Nessuna anomalia rilevata.")

# Visualizza le metriche
plt.figure(figsize=(10, 6))
plt.plot(mae_list, label='MAE')
plt.plot(mse_list, label='MSE')
plt.plot(rmse_list, label='RMSE')
plt.xlabel('Channel')
plt.ylabel('Metric Value')
plt.title('Metriche per Canale')
plt.legend()
plt.show()
# Out:
# --- Analisi MAE ---
# Media: 0.7713, Mediana: 0.7813
# Min: 0.1392, Max: 0.8073
# Anomalie rilevate nei canali: [28 34 37 53 60 61]
#
# --- Analisi MSE ---
# Media: 1.0080, Mediana: 1.0203
# Min: 0.1104, Max: 1.0777
# Anomalie rilevate nei canali: [28 34 53 60 61 62]
#
# --- Analisi RMSE ---
# Media: 1.0003, Mediana: 1.0101
# Min: 0.3323, Max: 1.0381
# Anomalie rilevate nei canali: [28 34 53 60 61 62]
